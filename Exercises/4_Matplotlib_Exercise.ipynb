# %% [markdown]
#  # Part 4: Matplotlib Exercise
#
#  Matplotlib is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms. Matplotlib can be used in Python scripts, the Python and IPython shells, the Jupyter notebook, web application servers, and four graphical user interface toolkits.
#  <br>
#  In this exercise, you'll learn the following:<br>
#  1. Matplotlib basics <br>
#  2. Matploblib single axis plots <br>
#  3. Matplotlib multiple axes plots<br>
#  4. Matplotlib and Pandas scatter plots and histograms<br>
#  <br>
#
#  Time to complete: 10 mins

# %% [markdown]
# ## Import Libraries and Initial Prep

# %%
import matplotlib.pyplot as plt # Importing the main matplotlib.pyplot library 'as' plt
import numpy as np # Importing numpy - we will use numpy to generate some random data to plot

# create a single dimensional numpy array between 0 and 10, with 100 points in between
x = np.linspace(0,10,100)

# %% [markdown]
# ## 1. Exercises
#
# Exercise 1.1 - Create a basic plot of the numpy array above using plt.plot(). Add in a label and a legend:

# %%
# Your answer for Exercise 1.1:

# plt.plot(?,?,label="")
# plt.?
# plt.show()

# %% [markdown]
# Exercise 1.2 - Create a plot with two axis, side by side.

# %%
# Your answer for Exercise 1.2:

# fig = plt.figure(figsize=(5,5))
# ax1 = fig.add_subplot(???)
# ax2 = fig.add_subplot(???)

# ax1.bar([1,2,3],[3,4,5])
# ax2.bar([1,2,3],[3,4,5])

# plt.show()

# %% [markdown]
# Exercise 1.3 - Create a histogram to explore data visualisation

# %%
# Your answer for Exercise 1.3:
# mu, sigma = 100, 15
# x = mu + sigma * np.random.randn(10000)

# n, bins, patches = plt.hist(?, 50, density=1, facecolor='g', alpha=0.75)


# plt.?label('Smarts')
# plt.?label('Probability')
# plt.title('Histogram of IQ')
# plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
# plt.axis([40, 160, 0, 0.03])
# plt.grid(True)
# plt.?

# %% [markdown]
# Exercise 1.4 - Create a pandas scatter matrix to evaluate machine learning suitability

# %%
# Your answer for Exercise 1.4:

# import numpy as np 
# import matplotlib.pyplot as plt 
# import pandas as pd 
# from IPython.display import display 
# from sklearn.datasets import load_iris 

# iris_dataset = load_iris()

# iris_df = ??.DataFrame(iris_dataset["data"], columns=iris_dataset["feature_names"]) 

# pd.plotting.scatter_matrix(??, c=iris_dataset["target"], figsize=(??, ??), marker='o', hist_kwds={'bins': 20}, s=60, alpha=.8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f425b294c88>,
# ...
#       dtype=object)
