# %% [markdown]
# # Part 3: Pandas Exercise
#
# Pandas was built on NumPy package and its key data structue is DataFrame. DataFrames allow you to store and manipulate tabular data in rows of observations and columns of variables. <br>
# <br>
# In this exercise, you'll learn the following:<br>
# 1. DataFrame Basics <br>
# 2. DataFrame Merge <br>
# 3. DataFrame groupby()<br>
# 4. DataFrame Filtering and Cleansing<br>
# <br>
#
# Time to complete: 20 mins

# %% [markdown]
# ## Import Pandas Library

# %%
import pandas as pd

# %% [markdown]
# ## 1. DataFrame Basics
#
# ### Exercise 1.1. Read CSV from the following url with seperator ";" and assign the dataframe to `bank_clients` variable.
# https://raw.githubusercontent.com/Kazolah/Data-Analysis-With-Python/master/bank-additional.csv

# %%
# Your answer for Exercise 1.1.
# bank_clients = pd.read_csv("", sep="")

# %% [markdown]
# ### Exercise 1.2. Print the first 5 rows of `bank_clients` dataframe.

# %%
# Your answer for Exercise 1.2. (Hint: use df.head())

# %% [markdown]
# ### Exercise 1.3. Print all columns of data frame `bank_clients`.

# %%
# Your answer for Exercise 1.3. (Hint: use df.columns)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %% [markdown]
# ### Exercise 1.4. Create a `new_bank_clients` data frame with the following conditions.
# `pdays == 999`, This indicates that customer was never contacted before for marketing campaign.

# %%
# Your answer for Exercise 1.4. (Hint: use new_df = df[df[column] `operator` number].copy())
new_bank_clients = 
new_bank_clients.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %% [markdown]
# ### Exercise 1.5. Select the value of 3rd rows and 2nd column  of `new_bank_clients` with `iloc[]`.

# %%
# Your answer for Exercise 1.5. (Hint: Rows and Column index starts from 0, df.iloc[row,column])
# Out:
# 'services'

# %% [markdown]
# ### Exercise 1.6. Capitalize ` job` column of `new_bank_clients` by following the lambda function

# %%
capitalizer = lambda x: x.capitalize()

# %%
# Your answer for Exercise 1.6. (Hint: df['index'].apply(function))
# Out:
# 0         Blue-collar
# 1            Services
# 2            Services
# 3            Services
# 4              Admin.
# 5            Services
# 6              Admin.
# 7        Entrepreneur
# 8            Services
# 9         Blue-collar
# 10           Services
# 11      Self-employed
# 12             Admin.
# 13        Blue-collar
# 14             Admin.
# 15           Services
# 16             Admin.
# 17             Admin.
# 18       Entrepreneur
# 19        Blue-collar
# 20           Services
# 22         Technician
# 23         Management
# 24         Technician
# 25         Technician
# 26         Technician
# 27        Blue-collar
# 28             Admin.
# 29             Admin.
# 30         Technician
#             ...
# 4087           Admin.
# 4089           Admin.
# 4090      Blue-collar
# 4091       Management
# 4092      Blue-collar
# 4093          Retired
# 4095           Admin.
# 4096         Services
# 4097      Blue-collar
# 4098        Housemaid
# ...

# %% [markdown]
# ## 2. DataFrame Merge

# %% [markdown]
# Import NumPy and generate data.

# %%
import numpy as np
contact_number = np.random.randint(97000000, high=99999999, size=4119)
cust_id = np.arange(1, 4120)

# %% [markdown]
# ### Exercise 2.1. Create a new data frame `customer_directory` with keys `contact_number` and `cust_id` with values from respective variables.

# %%
# Your answer for Exercise 2.1. Hint: use, df = pd.DataFrame({key: value})
customer_directory = 
customer_directory.head()
# Out:
#    contact_number  cust_id
# 0        97428471        1
# 1        98190688        2
# 2        98893689        3
# 3        97560161        4
# 4        99202165        5

# %% [markdown]
# ### Exercise 2.2. Create new index `cust_id` with value from `cust_id` variable in `bank_clients` data frame.

# %%
# Your answer for Exercise 2.2. (Hint: bank_clients['key'] = value)
bank_clients.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...    999         0  nonexistent
# 1  telephone   may         fri  ...    999         0  nonexistent
# 2  telephone   jun         wed  ...    999         0  nonexistent
# 3  telephone   jun         fri  ...    999         0  nonexistent
# 4   cellular   nov         mon  ...    999         0  nonexistent
#
#    emp.var.rate cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y  \
# ...

# %% [markdown]
# ### Exercise 2.3. Merge with left join `bank_clients` and `customer_directory` with key on `cust_id`.

# %%
# Your answer for Exercise 2.3. (Hint: pd.merge(df1, df2, how='left', on='key'))
# Out:
#       age            job   marital            education  default  housing  \
# 0      30    blue-collar   married             basic.9y       no      yes
# 1      39       services    single          high.school       no       no
# 2      25       services   married          high.school       no      yes
# 3      38       services   married             basic.9y       no  unknown
# 4      47         admin.   married    university.degree       no      yes
# 5      32       services    single    university.degree       no       no
# 6      32         admin.    single    university.degree       no      yes
# 7      41   entrepreneur   married    university.degree  unknown      yes
# 8      31       services  divorced  professional.course       no       no
# 9      35    blue-collar   married             basic.9y  unknown       no
# 10     25       services    single             basic.6y  unknown      yes
# 11     36  self-employed    single             basic.4y       no       no
# ...

# %% [markdown]
# ## 3. DataFrame `groupby()`

# %% [markdown]
# ### Exercise 3.1. Get minimum and maximum age for each job type from `bank_clients`.

# %%
# Your answer for Exercise 3.1. (Hint: df.groupby('index1').index2.agg(['min', 'max']))
# Out:
#                min  max
# job
# admin.          22   62
# blue-collar     20   71
# entrepreneur    23   60
# housemaid       23   85
# management      23   77
# retired         35   88
# self-employed   24   67
# services        21   60
# student         18   39
# technician      23   65
# unemployed      25   64
# unknown         24   66

# %% [markdown]
# ### Exercise 3.2. Discover what is mean age for the job from `bank_clients`.

# %%
# Your answer for Exercise 3.2. (Hint: df.groupby('index1').index2.mean())
# Out:
# job
# admin.           38.240119
# blue-collar      39.265837
# entrepreneur     42.202703
# housemaid        45.672727
# management       42.429012
# retired          60.873494
# self-employed    40.679245
# services         38.513995
# student          26.695122
# technician       38.622287
# unemployed       39.531532
# unknown          46.846154
# Name: age, dtype: float64

# %% [markdown]
# ### Exercise 3.3. Count the number of each job type from `bank_clients` dataframe.

# %%
# Your answer for Exercise 3.3. (Hint: use `df['index'].value_counts()`)
# Out:
# admin.           1012
# blue-collar       884
# technician        691
# services          393
# management        324
# retired           166
# self-employed     159
# entrepreneur      148
# unemployed        111
# housemaid         110
# student            82
# unknown            39
# Name: job, dtype: int64

# %% [markdown]
# ### 4. DataFrame Filtering and Cleansing
# This exercise will deal with new data set - Wine dataset.
#
# ### Import dataset

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'
wine = pd.read_csv(url)

wine.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %% [markdown]
# ### Exercise 4.1. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
# Your answer for Exercise 4.1. (Hint: List index starts from 0. Row is axis 0 and column is axis 1.)
# e.g. df = df.drop(df.columns[[i1,i2]], axis = 1)
wine.head()
# Out:
#    14.23  1.71  15.6  127  3.06  2.29  1.04
# 0  13.20  1.78  11.2  100  2.76  1.28  1.05
# 1  13.16  2.36  18.6  101  3.24  2.81  1.03
# 2  14.37  1.95  16.8  113  3.49  2.18  0.86
# 3  13.24  2.59  21.0  118  2.69  1.82  1.04
# 4  14.20  1.76  15.2  112  3.39  1.97  1.05

# %% [markdown]
# ### Exercise 4.2. Assign the columns as below:
# The attributes are: <br>
# 1) alcohol <br>
# 2) malic_acid <br>
# 3) alcalinity_of_ash <br>
# 4) magnesium <br>
# 5) flavanoids <br>
# 6) proanthocyanins <br>
# 7) hue

# %%
# Your answer for Exercise 4.2. (Hint: df.columns=['column1', 'column2'])
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    13.20        1.78               11.2        100        2.76
# 1    13.16        2.36               18.6        101        3.24
# 2    14.37        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### The following will set some values as NaN

# %%
wine.iloc[0:3, 0] = np.nan
wine.iloc[2:4, 3] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2      100.0        2.76
# 1      NaN        2.36               18.6      101.0        3.24
# 2      NaN        1.95               16.8        NaN        3.49
# 3    13.24        2.59               21.0        NaN        2.69
# 4    14.20        1.76               15.2      112.0        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Exercise 4.3. Count the number of missing values of `wine`

# %%
# Your answer for Exercise 4.3. (Hint: df.isnull().sum())
# Out:
# alcohol              3
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            2
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# ### Exercise 4.4. Delete the rows that contain missing values

# %%
# Your answer for Exercise 4.4. (Hint: df = df.dropna())
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 4    14.20        1.76               15.2      112.0        3.39
# 5    14.39        1.87               14.6       96.0        2.52
# 6    14.06        2.15               17.6      121.0        2.51
# 7    14.83        1.64               14.0       97.0        2.98
# 8    13.86        1.35               16.0       98.0        3.15
#
#    proanthocyanins   hue
# 4             1.97  1.05
# 5             1.98  1.02
# 6             1.25  1.06
# 7             1.98  1.08
# 8             1.85  1.01

# %% [markdown]
# ### Exercise 4.5. Reset the index, so it starts with 0 again.

# %%
# Your answer for Exercise 4.5. (Hint: df = df.reset_index(drop=True))
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    14.20        1.76               15.2      112.0        3.39
# 1    14.39        1.87               14.6       96.0        2.52
# 2    14.06        2.15               17.6      121.0        2.51
# 3    14.83        1.64               14.0       97.0        2.98
# 4    13.86        1.35               16.0       98.0        3.15
#
#    proanthocyanins   hue
# 0             1.97  1.05
# 1             1.98  1.02
# 2             1.25  1.06
# 3             1.98  1.08
# 4             1.85  1.01
